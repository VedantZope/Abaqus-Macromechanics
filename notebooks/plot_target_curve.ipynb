# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import os
from math import * 
os.getcwd()
print("The current directory is: ")
print(os.getcwd())
path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)
print("Moving up to the parent directory")
print(os.getcwd())
# Out:
# The current directory is:
# c:\Users\springnuance\Desktop\Abaqus-Macromechanics-Project\notebooks
# Moving up to the parent directory
# c:\Users\springnuance\Desktop\Abaqus-Macromechanics-Project

# %%
targetPathCurve1 = "SOO_targets/DP1000_room_Swift_NDBR50_curve2/FD_Curve.csv"
targetPathCurve2 = "SOO_targets/DP1000_room_SwiftVoce_NDBR50_curve2/FD_Curve.csv"
targetPathCurve3 = "SOO_targets/DP1000_room_SwiftVoce_NDBR50_curve1/FD_Curve.csv"
targetPathCurve4 = "SOO_targets/DP1000_400C_SwiftVoce_NDBR50_curve1/FD_Curve.csv"

# Plot all target curves
targetCurve1 = pd.read_csv(targetPathCurve1)
targetCurve2 = pd.read_csv(targetPathCurve2)
targetCurve3 = pd.read_csv(targetPathCurve3)
targetCurve4 = pd.read_csv(targetPathCurve4)

# Plot all target curves
plt.figure(figsize=(8,6))
plt.plot(targetCurve1['displacement/mm'], targetCurve1['force/N'], label='DP1000_room_Swift_NDBR50_curve2')
plt.plot(targetCurve2['displacement/mm'], targetCurve2['force/N'], label='DP1000_room_SwiftVoce_NDBR50_curve2')
plt.plot(targetCurve3['displacement/mm'], targetCurve3['force/N'], label='DP1000_room_SwiftVoce_NDBR50_curve1')
plt.plot(targetCurve4['displacement/mm'], targetCurve4['force/N'], label='DP1000_400C_SwiftVoce_NDBR50_curve1')
plt.xlabel('Displacement/mm')
plt.ylabel('Force/N')
plt.legend()
